# %%
import openai
openai.api_key = ""

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
text = """
[
    {
        "title": "Such an epic camera",
        "rating": "5.0 out of 5 stars",
        "body": "The G9 has been a revelation. I bought it as a cheaper way into birding photography. Used with the Panasonic 100-300 II. Absolutely stunning. Then decided to try the G9 for more things. So bought the 12-60 for landscapes, using the 100-300 for tighter crops. Absolutely love it for landscapes. The high Res mode works well for 40mp and 80mp images. Added the Olympus 45mm for portraits. And the Panasonic 20mm II for street and general walk about photography. Stopped using my Sony A7R II, just enjoy using the Panasonic system far more.Worth noting that the G9 is not a small camera. Quite a bit larger than the A7 body. But the G9 is perfect in the hand. With epic controls, stunning EVF, great LCD, awesome stabilization. Knocks spots of the Sony."
    },
    {
        "title": "Excellent camera",
        "rating": "5.0 out of 5 stars",
        "body": "Bought this as a second camera to go alongside my GH5 but I find this is so good for stills it's become my primary photo camera. Video features are excellent too"
    },
      {
        "title": "Excellent camera",
        "rating": "2.0 out of 5 stars",
        "body": "The bad stuff first:
            1. Unusable as a photo camera for me, with the 12-60 Leica, the images don't have any detail, even at 200 ISO. It is really absolutely terrible. Even my old Nikon D5300 with the crappy kit lens produces images with more detail.
            2. Video is OK, like it more than my Sony A7 III.
            3. Ergonomics and functions are really top.
            Conclusion: Very nice and ergonomically awesome equipment, but not usable in photos.
            Have to return it."
    },
      {
        "title": "Excellent camera",
        "rating": "5.0 out of 5 stars",
        "body": "Pior camera que já utilizei.As imagens não têm detalhe. E a bateria dura pouquissimo."
    }

]
"""

prompt = f"""
First, check if any reviews are not in English. If not, translate them.
Given the following user reviews for the same product.

Review Analysis:
1. Average rating
2. Identify the best features.
3. Identify the worst features.
4. Extract a list of emotions without any examples.

The reviews are in a JSON file where the reviews are in the field "body", 
and the rating from the "rating" field.
{text}
"""

response = get_completion(prompt)
print(response)

# %%
text_2 = """
[
    {
        "title": "Such an epic camera",
        "rating": "5.0 out of 5 stars",
        "body": "The G9 has been a revelation. I bought it as a cheaper way into birding photography. Used with the Panasonic 100-300 II. Absolutely stunning. Then decided to try the G9 for more things. So bought the 12-60 for landscapes, using the 100-300 for tighter crops. Absolutely love it for landscapes. The high Res mode works well for 40mp and 80mp images. Added the Olympus 45mm for portraits. And the Panasonic 20mm II for street and general walk about photography. Stopped using my Sony A7R II, just enjoy using the Panasonic system far more.Worth noting that the G9 is not a small camera. Quite a bit larger than the A7 body. But the G9 is perfect in the hand. With epic controls, stunning EVF, great LCD, awesome stabilization. Knocks spots of the Sony."
    },
    {
        "title": "Excellent camera",
        "rating": "5.0 out of 5 stars",
        "body": "Bought this as a second camera to go alongside my GH5 but I find this is so good for stills it's become my primary photo camera. Video features are excellent too"
    },
      {
        "title": "Excellent camera",
        "rating": "2.0 out of 5 stars",
        "body": "The bad stuff first:
            1. Unusable as a photo camera for me, with the 12-60 Leica, the images don't have any detail, even at 200 ISO. It is really absolutely terrible. Even my old Nikon D5300 with the crappy kit lens produces images with more detail.
            2. Video is OK, like it more than my Sony A7 III.
            3. Ergonomics and functions are really top.
            Conclusion: Very nice and ergonomically awesome equipment, but not usable in photos.
            Have to return it."
    },
      {
        "title": "Excellent camera",
        "rating": "5.0 out of 5 stars",
        "body": "Pior camera que já utilizei.As imagens não têm detalhe. E a bateria dura pouquissimo."
    }

]
"""

prompt = f"""
First, check if any reviews are not in English. If not, translate them.
Given the following user reviews for the same product.

Review Analysis:
1. Average rating
2. Identify the best features in topics.
2.1 Resume of what was said about each feature.
3. Identify the worst features in topics.
3.1 Resume of what was said about each feature.
4. Extract a list of emotions without any examples.

do not say in what language the review was written. 

Follow this structure:
Average rating :

Best Features :
-feature: resume 

Best Features :
-feature: resume 

List of emotions:
-emotion


The reviews are in a JSON file where the reviews are in the field "body", 
and the rating from the "rating" field.
{text_2}
"""

response = get_completion(prompt)
print(response)

# %%
text_2 = """
[
    {
        "title": "Such an epic camera",
        "rating": "5.0 out of 5 stars",
        "body": "The G9 has been a revelation. I bought it as a cheaper way into birding photography. Used with the Panasonic 100-300 II. Absolutely stunning. Then decided to try the G9 for more things. So bought the 12-60 for landscapes, using the 100-300 for tighter crops. Absolutely love it for landscapes. The high Res mode works well for 40mp and 80mp images. Added the Olympus 45mm for portraits. And the Panasonic 20mm II for street and general walk about photography. Stopped using my Sony A7R II, just enjoy using the Panasonic system far more.Worth noting that the G9 is not a small camera. Quite a bit larger than the A7 body. But the G9 is perfect in the hand. With epic controls, stunning EVF, great LCD, awesome stabilization. Knocks spots of the Sony."
    },
    {
        "title": "Excellent camera",
        "rating": "5.0 out of 5 stars",
        "body": "Bought this as a second camera to go alongside my GH5 but I find this is so good for stills it's become my primary photo camera. Video features are excellent too"
    },
      {
        "title": "Excellent camera",
        "rating": "2.0 out of 5 stars",
        "body": "The bad stuff first:
            1. Unusable as a photo camera for me, with the 12-60 Leica, the images don't have any detail, even at 200 ISO. It is really absolutely terrible. Even my old Nikon D5300 with the crappy kit lens produces images with more detail.
            2. Video is OK, like it more than my Sony A7 III.
            3. Ergonomics and functions are really top.
            Conclusion: Very nice and ergonomically awesome equipment, but not usable in photos.
            Have to return it."
    },
      {
        "title": "Excellent camera",
        "rating": "5.0 out of 5 stars",
        "body": "Pior camera que já utilizei.As imagens não têm detalhe. E a bateria dura pouquissimo."
    }

]
"""

prompt = f"""

Analyze the following collection of reviews and employ topic modeling techniques to categorize
the feedback into specific features of the product.
First, check if any reviews are not in English. If not, translate them.
Then identify the positive characteristics and the negative characteristics.

Provide only the structure bellow:
  Average rating :

  Positive characteristics :
  -characteristics name: reason why is positive and i do not want quotes from the reviews

  Negative characteristics :
  -characteristics name: reason why is negative and i do not want quotes from the reviews

The reviews are in a JSON file where the reviews are in the field "body", 
and the rating from the "rating" field.

Review text: '''{text}'''
"""

response = get_completion(prompt)
print(response)
# Out:
# Average rating: 4.25
#
# Positive characteristics:
# - Image quality: The camera produces stunning images, especially for birding and landscapes.
# - Video features: The camera has excellent video features.
# - Ergonomics and functions: The camera has great ergonomics and functions, making it easy to use.
#
# Negative characteristics:
# - Image quality: The camera produces images with no detail, making it unusable for some users.
# - Battery life: The battery life is very short.
